# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.dml.color import RGBColor
from pptx.enum.text import PP_ALIGN

def create_slide(prs, title, content):
    slide = prs.slides.add_slide(prs.slide_layouts[1])
    
    # Título
    title_shape = slide.shapes.title
    title_shape.text = title
    title_shape.text_frame.paragraphs[0].font.size = Pt(32)
    title_shape.text_frame.paragraphs[0].font.bold = True
    title_shape.text_frame.paragraphs[0].font.color.rgb = RGBColor(31, 73, 125)
    
    # Contenido
    content_shape = slide.shapes.placeholders[1]
    text_frame = content_shape.text_frame
    text_frame.text = content
    text_frame.paragraphs[0].font.size = Pt(18)
    
    return slide

# Crear presentación
prs = Presentation()

# Diapositiva 1: Portada
slide = prs.slides.add_slide(prs.slide_layouts[0])
title = slide.shapes.title
subtitle = slide.shapes.placeholders[1]
title.text = "Flexibilidad Laboral y Políticas de Protección del Empleo"
subtitle.text = "Un Análisis del Mercado Laboral Español"

# Contenido de las diapositivas
slides_content = [
    ("Concepto de Flexibilidad Laboral", 
     "La flexibilidad laboral representa uno de los pilares fundamentales en la configuración de las políticas de empleo contemporáneas. Su importancia ha crecido exponencialmente en las últimas décadas, especialmente tras las profundas transformaciones experimentadas en los mercados de trabajo globales.\n\n"
     "Este concepto trasciende su aplicación puramente laboral, constituyéndose como un mecanismo esencial para la adaptación y mejora de los niveles de competitividad de toda la economía. La pandemia de COVID-19 ha actuado como catalizador, acelerando una tendencia que ya estaba en marcha: la necesidad de una fuerza laboral más adaptable y resiliente."),
    
    ("Evolución Histórica", 
     "Desde los años setenta del siglo XX, la flexibilidad ha sido el concepto clave tanto en la discusión teórica como en las reformas legales y empresariales. Este período marca el inicio de una transformación profunda en la concepción de las relaciones laborales.\n\n"
     "Sin embargo, es importante destacar que, pese a la intensidad de los cambios introducidos durante décadas, muchos de los problemas históricos de los mercados de trabajo no se han resuelto por la mera introducción de reformas generalistas. Esto sugiere la necesidad de un enfoque más matizado y contextualizado."),
    
    ("Dimensiones Fundamentales",
     "La flexibilidad laboral se articula en dos dimensiones principales que definen su aplicación práctica:\n\n"
     "1. Flexibilidad Externa: Se refiere a la capacidad empresarial para realizar ajustes en la plantilla mediante la contratación y el despido de trabajadores. Esta dimensión ha sido tradicionalmente la más utilizada en el contexto español.\n\n"
     "2. Flexibilidad Interna: Engloba la capacidad para modificar las condiciones de empleo y la organización del trabajo dentro de la propia empresa, sin necesidad de alterar el tamaño de la plantilla."),
    
    ("Flexibilidad Externa: Conceptualización",
     "La flexibilidad externa constituye un elemento fundamental en la gestión del mercado laboral español. Se materializa a través de dos flujos principales:\n\n"
     "El flujo de entrada al empleo está determinado por los costes y requisitos asociados a la contratación, incluyendo tanto aspectos monetarios como administrativos. El flujo de salida se relaciona con los costes y procedimientos vinculados al despido.\n\n"
     "Esta dimensión de la flexibilidad ha sido históricamente predominante en España, configurando un modelo particular de ajuste del mercado laboral."),
    
    ("Profesionalización de la Contratación",
     "En los últimos años se ha observado una creciente profesionalización del proceso de contratación, especialmente en las grandes empresas. Esta tendencia se ha manifestado en:\n\n"
     "- La descentralización y externalización de la gestión de personal\n"
     "- El surgimiento de empresas especializadas en selección\n"
     "- La evolución de las Empresas de Trabajo Temporal\n"
     "- El desarrollo de nuevas formas de intermediación laboral\n\n"
     "Esta profesionalización busca optimizar los procesos de contratación y mejorar el ajuste entre oferta y demanda de trabajo."),
    
    ("Mecanismos de Flexibilización Externa",
     "El mercado laboral español ha desarrollado diversos mecanismos para implementar la flexibilidad externa:\n\n"
     "1. La utilización estratégica de contratos temporales como principal vía de ajuste\n"
     "2. El desarrollo de un marco regulatorio para las ETTs que facilita la adaptación rápida\n"
     "3. La promoción del trabajo autónomo como forma de flexibilización\n"
     "4. La utilización de contratas y subcontratas para externalizar actividades\n\n"
     "Estos mecanismos han configurado un modelo particular de flexibilidad con importantes implicaciones para el mercado laboral."),
    
    ("Protección del Empleo: Marco General",
     "El sistema español de protección al empleo se caracteriza por:\n\n"
     "- Una regulación detallada de las causas y procedimientos de despido\n"
     "- Un sistema de indemnizaciones relativamente elevado para contratos indefinidos\n"
     "- La distinción entre despidos procedentes e improcedentes\n"
     "- Procedimientos especiales para despidos colectivos\n\n"
     "Este marco busca equilibrar la necesaria flexibilidad empresarial con la protección de los derechos laborales."),
    
    ("Indicadores de Protección al Empleo",
     "El índice EPL de la OCDE proporciona una medida comparativa internacional de la protección laboral. Para España, este índice revela:\n\n"
     "- Una protección media-alta en comparación con otros países OCDE\n"
     "- Costes de despido superiores a la media para contratos indefinidos\n"
     "- Una regulación más estricta para despidos colectivos\n"
     "- Mayor flexibilidad en la contratación temporal\n\n"
     "Estas características han influido significativamente en la configuración del mercado laboral español."),
    
    ("Flexibilidad Interna: Marco Conceptual",
     "La flexibilidad interna permite a las empresas adaptarse a los cambios del entorno económico sin modificar el tamaño de su plantilla. Sus principales manifestaciones son:\n\n"
     "1. Adaptación de jornadas y horarios\n"
     "2. Modificación de funciones y tareas\n"
     "3. Ajustes salariales\n"
     "4. Movilidad geográfica\n\n"
     "Esta forma de flexibilidad ha ganado relevancia como alternativa a los ajustes vía empleo."),
    
    ("Flexibilidad Numérica Interna",
     "La capacidad de ajustar el tiempo de trabajo sin modificar la plantilla se ha revelado como una herramienta fundamental, especialmente durante crisis económicas. Sus principales manifestaciones incluyen:\n\n"
     "- La reducción temporal de jornada\n"
     "- Los contratos a tiempo parcial\n"
     "- Los contratos fijos discontinuos\n"
     "- La distribución irregular de la jornada\n\n"
     "La experiencia durante la pandemia ha demostrado la efectividad de estos mecanismos para preservar el empleo."),
    
    ("Flexibilidad Funcional y Formación",
     "La capacidad de adaptar las funciones de los trabajadores requiere una estrategia integral que incluye:\n\n"
     "- Sistemas de clasificación profesional flexibles\n"
     "- Programas de formación continua\n"
     "- Desarrollo de competencias transversales\n"
     "- Políticas de promoción interna\n\n"
     "La inversión en capital humano resulta fundamental para el éxito de esta dimensión de la flexibilidad."),
    
    ("Flexibilidad Salarial",
     "Los mecanismos de ajuste salarial en España se caracterizan por:\n\n"
     "- Un sistema de negociación colectiva que establece salarios mínimos sectoriales\n"
     "- Complementos salariales vinculados a productividad\n"
     "- Cláusulas de descuelgue para situaciones económicas adversas\n"
     "- Mecanismos de revisión salarial ligados a la inflación\n\n"
     "La efectividad de estos mecanismos influye directamente en la competitividad empresarial."),
    
    ("Impacto en la Calidad del Empleo",
     "La implementación de diferentes formas de flexibilidad ha tenido efectos significativos en la calidad del empleo:\n\n"
     "- Alta temporalidad y rotación laboral\n"
     "- Disparidades salariales según tipo de contrato\n"
     "- Diferencias en acceso a formación\n"
     "- Impacto en la productividad\n\n"
     "Estos efectos plantean desafíos importantes para la política laboral."),
    
    ("Dualidad del Mercado Laboral",
     "El mercado laboral español se caracteriza por una marcada dualidad:\n\n"
     "- Trabajadores con contratos indefinidos y alta protección\n"
     "- Trabajadores temporales con menor estabilidad y derechos\n"
     "- Diferencias significativas en condiciones laborales\n"
     "- Impacto desigual de los ciclos económicos\n\n"
     "Esta dualidad representa uno de los principales retos estructurales."),
    
    ("Reformas Laborales Recientes",
     "Las últimas reformas laborales han buscado abordar los problemas estructurales del mercado laboral:\n\n"
     "- Reforma 2012: Flexibilización y descentralización de la negociación colectiva\n"
     "- Reforma 2021: Refuerzo de la contratación indefinida y limitación de temporalidad\n"
     "- Nuevos mecanismos de flexibilidad interna\n"
     "- Modificación de la estructura de la negociación colectiva"),
    
    ("Experiencia Durante la Pandemia",
     "La crisis del COVID-19 ha proporcionado importantes lecciones sobre flexibilidad laboral:\n\n"
     "- Efectividad de los ERTE como mecanismo de ajuste\n"
     "- Importancia de la flexibilidad interna\n"
     "- Adaptación al teletrabajo\n"
     "- Necesidad de mecanismos permanentes de ajuste temporal\n\n"
     "Estas experiencias deberían informar el diseño de futuras políticas laborales."),
    
    ("Desafíos Futuros",
     "El mercado laboral español enfrenta importantes retos que requieren atención:\n\n"
     "- Reducción de la dualidad laboral\n"
     "- Mejora de la productividad\n"
     "- Adaptación a la digitalización\n"
     "- Fortalecimiento de la formación continua\n"
     "- Desarrollo de mecanismos efectivos de flexibilidad interna"),
    
    ("Conclusiones",
     "La experiencia española en materia de flexibilidad laboral muestra:\n\n"
     "1. La necesidad de equilibrar flexibilidad y seguridad\n"
     "2. La importancia de desarrollar mecanismos de flexibilidad interna\n"
     "3. El impacto de la regulación en la estructura del mercado laboral\n"
     "4. La relevancia de la formación y la adaptabilidad\n\n"
     "El éxito futuro dependerá de la capacidad para abordar estos aspectos de manera integral y equilibrada."),
    
    ("Recomendaciones",
     "Para mejorar el funcionamiento del mercado laboral español se sugiere:\n\n"
     "1. Fortalecer los mecanismos de flexibilidad interna\n"
     "2. Invertir en formación y desarrollo de competencias\n"
     "3. Modernizar la negociación colectiva\n"
     "4. Desarrollar políticas activas de empleo más efectivas\n"
     "5. Promover un marco regulatorio que favorezca la adaptabilidad sin precarizar el empleo")
]

# Crear las diapositivas
for title, content in slides_content:
    create_slide(prs, title, content)

# Guardar la presentación
prs.save(r'C:\Users\Usuario\Dropbox\DOCENCIA UPO\CURSO 24-25\Pssll\Temas EB\Tema 7\Flexibilidad_Laboral_España.pptx')
